# %% [markdown]
# <a href="https://colab.research.google.com/github/nerdropy/Machine-Learning-Projects/blob/master/prediction/MLP_Lung_Cancer/MLP_Lung_Cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ! kaggle datasets download mysarahmadbhat/lung-cancer
# ! unzip lung-cancer.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mysarahmadbhat/lung-cancer
# License(s): CC0-1.0
# lung-cancer.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  lung-cancer.zip
# replace survey lung cancer.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('survey lung cancer.csv')

df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

df['LUNG_CANCER'] = le.fit_transform(df['LUNG_CANCER'])
df['GENDER']= le.fit_transform(df['GENDER'])
df.head()
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       1   69        1               2        2              1
# 1       1   74        2               1        1              1
# 2       0   59        1               1        1              2
# 3       1   63        2               2        2              1
# 4       0   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# ...

# %%
X = df.iloc[:, 0:-1]
y = df[['LUNG_CANCER']]


from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier(hidden_layer_sizes=(6, 5),
                    random_state=5,
                    verbose=True,
                    learning_rate_init=0.01)
clf.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1098: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 7.03779942
# Iteration 2, loss = 5.43737569
# Iteration 3, loss = 4.05808288
# Iteration 4, loss = 2.85161427
# Iteration 5, loss = 1.82943809
# Iteration 6, loss = 1.21986665
# Iteration 7, loss = 0.95568225
# Iteration 8, loss = 0.89405147
# Iteration 9, loss = 0.83926551
# Iteration 10, loss = 0.78514431
# Iteration 11, loss = 0.73251938
# Iteration 12, loss = 0.67916728
# Iteration 13, loss = 0.62613836
# Iteration 14, loss = 0.57682409
# Iteration 15, loss = 0.53189149
# Iteration 16, loss = 0.49407978
# Iteration 17, loss = 0.46296411
# Iteration 18, loss = 0.44026218
# Iteration 19, loss = 0.42662613
# Iteration 20, loss = 0.41720005
# Iteration 21, loss = 0.41717080
# ...

# %%
ypred = clf.predict(X_test)

from sklearn.metrics import accuracy_score

accuracy_score(y_test, ypred)
# Out:
# 0.9247311827956989
